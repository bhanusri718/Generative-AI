# %%
#!pip install -q langchain langchain_core langchain_community sentence_transformers faiss-cpu unstructured chromadb Cython tiktoken unstructured[local-inference] langchain_groq

# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
   os.environ["GROQ_API_KEY"] = getpass.getpass("Provide your GROQ API TOKEN")

# %%
# !pip install -U langchain-community

# %%
pip install langchain

# %%
# Document Loader
from langchain.document_loaders import TextLoader
loader = TextLoader('/content/About India, cricket.txt')
documents = loader.load()

# %%
ls /content/
# Out:
# 'About India, cricket.txt'   sample_data/

# %%
documents
# Out:
# [Document(metadata={'source': '/content/About India, cricket.txt'}, page_content="essay about india\n\nIndia, a land of myriad cultures, traditions, and landscapes, stands as a beacon of diversity and resilience in the global tapestry. With a rich history spanning thousands of years, India's story is one of ancient civilizations, dynasties, and profound philosophical insights that continue to shape its identity today.\n\nGeographically, India boasts a breathtaking diversity from the towering Himalayas in the north to the sun-kissed beaches of the south, and from the arid deserts of Rajasthan to the lush forests of Kerala. This diversity extends to its people, who speak hundreds of languages and practice multiple religions, creating a mosaic of cultures that is both vibrant and complex.\n\nIndia's history is marked by the rise and fall of empires such as the Mauryas, Guptas, and Mughals, each leaving a lasting imprint on the country's architecture, art, and societal norms. The country
# ...

# %%
import textwrap

def wrap_text_preserve_newlines(text, width=110):
    # Split the input text into lines based on newline characters
    lines = text.split('\n')

    # Wrap each line individually
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    # Join the wrapped lines back together using newline characters
    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text

# %%
print(wrap_text_preserve_newlines(str(documents[0])))
# Out:
# page_content='essay about india
#
# India, a land of myriad cultures, traditions, and landscapes, stands as a beacon of diversity and resilience
# in the global tapestry. With a rich history spanning thousands of years, India's story is one of ancient
# civilizations, dynasties, and profound philosophical insights that continue to shape its identity today.
#
# Geographically, India boasts a breathtaking diversity from the towering Himalayas in the north to the sun-
# kissed beaches of the south, and from the arid deserts of Rajasthan to the lush forests of Kerala. This
# diversity extends to its people, who speak hundreds of languages and practice multiple religions, creating a
# mosaic of cultures that is both vibrant and complex.
#
# India's history is marked by the rise and fall of empires such as the Mauryas, Guptas, and Mughals, each
# leaving a lasting imprint on the country's architecture, art, and societal norms. The country's spiritual
# ...

# %%
# Text Splitter
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# %%
len(docs)
# Out:
# 9

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()
# Out:
# <ipython-input-22-a8d3548f7db6>:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings()
# <ipython-input-22-a8d3548f7db6>:3: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings()
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 54.2 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import FAISS

db = FAISS.from_documents(docs, embeddings)

# %%
query = "explain about indian premier league"
docs = db.similarity_search(query)

# %%
print(wrap_text_preserve_newlines(str(docs[0].page_content)))
# Out:
# The Indian Premier League (IPL), launched in 2008, revolutionized the cricketing landscape by blending
# entertainment with top-notch cricketing action. The league's success has not only attracted global stars but
# also provided a platform for young Indian players to showcase their talent and earn recognition on a grand
# stage.
#
# Cricket in India is not just about the players and matches; it's also about the fans who pack stadiums, paint
# their faces in team colors, and live and breathe every moment of the game. The fervor surrounding cricket
# transcends generations, with families gathering around television sets or radios to cheer for their favorite
# players and teams.

# %%
##CREATE LLM

# %%
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 10.4 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["GROQ_API_KEY"] = "xai-TPzmgmqIV9EZb6Qcs1zhWFK0mxj0oL1PjtXh55xEfZ94sZZ0LgYuwBboPTvJPQymjAxRLXxSYnu6VIju"

# %%
import langchain_groq #This import remains the same, in case the package requires importing with an underscore to load submodules
from langchain_groq import ChatGroq

GROQ_LLM = ChatGroq(
            api_key=os.getenv("GROQ_API_KEY"),
            model="gemma2-9b-it"
        )

# %%
import langchain_groq
from langchain_groq import ChatGroq

GROQ_LLM = ChatGroq(
            api_key=os.getenv("GROQ_API_KEY"),
            model="gemma2-9b-it"
        )

# %%
from langchain.chains.question_answering import load_qa_chain

chain = load_qa_chain(GROQ_LLM, chain_type="stuff")
# Out:
# <ipython-input-31-95de09154617>:3: LangChainDeprecationWarning: This class is deprecated. See the following migration guides for replacements based on `chain_type`:
# stuff: https://python.langchain.com/docs/versions/migrating_chains/stuff_docs_chain
# map_reduce: https://python.langchain.com/docs/versions/migrating_chains/map_reduce_chain
# refine: https://python.langchain.com/docs/versions/migrating_chains/refine_chain
# map_rerank: https://python.langchain.com/docs/versions/migrating_chains/map_rerank_docs_chain
#
# See also guides on retrieval and question-answering here: https://python.langchain.com/docs/how_to/#qa-with-rag
#   chain = load_qa_chain(GROQ_LLM, chain_type="stuff")

# %%
query = "HOW IS INDIAN ECONOMY"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-55-5832714cf385> in <cell line: 0>()
#       1 query = "HOW IS INDIAN ECONOMY"
#       2 docs = db.similarity_search(query)
# ----> 3 chain.run(input_documents=docs, question=query)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     186                 warned = True
#     187                 emit_warning()
# --> 188             return wrapped(*args, **kwargs)
#     189
#     190         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     609
#     610         if kwargs and not args:
# --> 611             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
# ...

# %%
query = "explain about indian geograpy?"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-56-acee7e36d2bc> in <cell line: 0>()
#       1 query = "explain about indian geograpy?"
#       2 docs = db.similarity_search(query)
# ----> 3 chain.run(input_documents=docs, question=query)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     186                 warned = True
#     187                 emit_warning()
# --> 188             return wrapped(*args, **kwargs)
#     189
#     190         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     609
#     610         if kwargs and not args:
# --> 611             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
# ...
